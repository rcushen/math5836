# %% [markdown]
# # Project 1 (Case 2)
# In this section we investigate the effects of COVID-10 on prediction accuracy using a neural network applied to the historic trading prices for CBA.

# %% [markdown]
# ## Exploratory data analysis
# We begin by importing the data and generating some summary visuals.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import TensorDataset, DataLoader

from sklearn.model_selection import train_test_split

from sklearn import preprocessing

from sklearn.linear_model import LinearRegression

from matplotlib.gridspec import GridSpec

# %%
raw_data = pd.read_csv('../data/CBA.AX.csv', parse_dates=['Date'])
raw_data = raw_data.set_index('Date')

# %%
raw_data['Close'].plot(title='CBA stock price 2017-10 to 2020-10')
plt.show()

# %% [markdown]
# The large drop during COVID-19 is very clear. I will take it that the date COVID-19 started is 15/2/2020.

# %% [markdown]
# ## Feature Engineering
# First we will need to use the time series to construct some features which will be used for prediction.

# %%
series = raw_data['Close']

# %%
series_standardised = (series - series.mean()) / series.std()

# %%
def generate_features(series, n_features, steps_ahead):
    len_series = len(series)
    X, y = [], []
    for i in range(len_series - n_features - steps_ahead):
        Xs, ys = series[i:i+n_features].values, series[i+n_features:i+n_features+steps_ahead].values
        X.append(Xs)
        y.append(ys)
    X, y = np.vstack(X), np.vstack(y)
    return X, y

# %%
X, y = generate_features(series_standardised, n_features=5, steps_ahead=5)

# %%
covid_date_index = len(series[:'2020-02-17'])
covid_date_index_plus_50_perc = int(covid_date_index + np.floor((len(series) - covid_date_index)/2))

# %%
X_train_1, y_train_1 = X[:covid_date_index], y[:covid_date_index]
X_test_1, y_test_1 = X[covid_date_index:], y[covid_date_index:]

X_train_2, y_train_2 = X[:covid_date_index_plus_50_perc], y[:covid_date_index_plus_50_perc]
X_test_2, y_test_2 = X[covid_date_index_plus_50_perc:], y[covid_date_index_plus_50_perc:]

# %% [markdown]
# ## Experimenting with a simple classifier
# Before building a neural network, we first experiment with a simple linear regression. This is simply multiple-output regression, where a model is fit for each of the $5$ outputs.

# %%
model_1 = LinearRegression()

model_1.fit(X_train_1, y_train_1)
print('Model 1 R2: {:.4f}'.format(model_1.score(X_test_1,y_test_1)))

model_2 = LinearRegression()

model_2.fit(X_train_2, y_train_2)
print('Model 2 R2: {:.4f}'.format(model_2.score(X_test_2, y_test_2)))
# Out:
# Model 1 R2: 0.7008
# Model 2 R2: 0.7387

# %% [markdown]
# Unsurprisingly, baseline performance improves when we consider more data from the COVID-19 period.

# %% [markdown]
# ## Building a neural network
# We now proceed to building a baseline neural network, which will later be improved upon.

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(5,32)
        self.fc2 = nn.Linear(32,5)
        
        self.activation = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        
        return x

# %%
model = Net()

# %% [markdown]
# ## Training a neural network
# We are now ready to train our neural network.

# %%
train_dataset = TensorDataset(
    torch.from_numpy(X_train_1).type(torch.float),
    torch.from_numpy(y_train_1).type(torch.float),
)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

test_dataset = TensorDataset(
    torch.from_numpy(X_test_1).type(torch.float),
    torch.from_numpy(y_test_1).type(torch.float),
)

test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
model = Net()

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.0005)

# %%
n_epochs = 250

train_losses = []
test_losses = []

for e in range(n_epochs):
    
    model.train()
    for ii, (inputs, responses) in enumerate(train_dataloader):
        optimizer.zero_grad() 

        output = model(inputs)
        loss = criterion(output, responses)

        loss.backward()
        optimizer.step()

        train_losses.append(loss.item() / inputs.shape[0])
    
    
    test_loss = 0
    
    model.eval()
    for ii, (inputs, responses) in enumerate(test_dataloader):
        with torch.no_grad():
            output = model(inputs)
            loss = criterion(output, responses)

            test_loss += loss.item() / inputs.shape[0]
        
    test_losses.append(test_loss)

# %%
window_length = 25
train_losses_averaged = np.convolve(np.array(train_losses), 
                                    np.ones((window_length,)) / window_length, 
                                    mode='valid')

# %%
model.eval()
with torch.no_grad():
    predictions = model(torch.from_numpy(X).type(torch.float)).numpy()
    
predictions_1step = pd.Series(predictions[:,0], index=series_standardised.index[5:-5])
predictions_5step = pd.Series(predictions[:,4], index=series_standardised.index[5:-5])

# %%
fig = plt.figure(figsize=(20,12))
gs = GridSpec(2, 2, figure=fig)
ax1 = plt.subplot(gs[0, :])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[1, 1])

ax1.plot(train_losses_averaged)
ax2.plot(test_losses)

ax3.plot(series_standardised[5:-5], label='Actuals')
ax3.plot(predictions_1step, label='1-step prediction', alpha=0.6)
ax3.plot(predictions_5step, label='5-step prediction', alpha=0.6)
ax3.legend(loc='lower left')

ax1.set_title('Training loss (per 25 batches)')
ax1.set_xlabel('Batch')
ax1.set_ylabel('Loss')

ax2.set_title('Test loss (per epoch)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')

ax3.set_title('Actuals vs predictions')
ax3.set_xlabel('Date')
ax3.set_ylabel('Standardised Price')

plt.show()

# %% [markdown]
# Training loss flattens out, but test loss is messy. This is made doubly clear in the large gap between predictions and actuals during the COVID-19 period. Let us try again with the same model but using instead 50% of the training data from the COVID-19 period.

# %%
train_dataset = TensorDataset(
    torch.from_numpy(X_train_2).type(torch.float),
    torch.from_numpy(y_train_2).type(torch.float),
)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

test_dataset = TensorDataset(
    torch.from_numpy(X_test_2).type(torch.float),
    torch.from_numpy(y_test_2).type(torch.float),
)

test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
model = Net()

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.0005)

# %%
n_epochs = 250

train_losses = []
test_losses = []

for e in range(n_epochs):
    
    model.train()
    for ii, (inputs, responses) in enumerate(train_dataloader):
        optimizer.zero_grad() 

        output = model(inputs)
        loss = criterion(output, responses)

        loss.backward()
        optimizer.step()

        train_losses.append(loss.item() / inputs.shape[0])
    
    
    test_loss = 0
    
    model.eval()
    for ii, (inputs, responses) in enumerate(test_dataloader):
        with torch.no_grad():
            output = model(inputs)
            loss = criterion(output, responses)

            test_loss += loss.item() / inputs.shape[0]
        
    test_losses.append(test_loss)

# %%
window_length = 25
train_losses_averaged = np.convolve(np.array(train_losses), 
                                    np.ones((window_length,)) / window_length, 
                                    mode='valid')

# %%
model.eval()
with torch.no_grad():
    predictions = model(torch.from_numpy(X).type(torch.float)).numpy()
    
predictions_1step = pd.Series(predictions[:,0], index=series_standardised.index[5:-5])
predictions_5step = pd.Series(predictions[:,4], index=series_standardised.index[5:-5])

# %%
fig = plt.figure(figsize=(20,12))
gs = GridSpec(2, 2, figure=fig)
ax1 = plt.subplot(gs[0, :])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[1, 1])

ax1.plot(train_losses_averaged)
ax2.plot(test_losses)

ax3.plot(series_standardised[5:-5], label='Actuals')
ax3.plot(predictions_1step, label='1-step prediction', alpha=0.6)
ax3.plot(predictions_5step, label='5-step prediction', alpha=0.6)
ax3.legend(loc='lower left')

ax1.set_title('Training loss (per 25 batches)')
ax1.set_xlabel('Batch')
ax1.set_ylabel('Loss')

ax2.set_title('Test loss (per epoch)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')

ax3.set_title('Actuals vs predictions')
ax3.set_xlabel('Date')
ax3.set_ylabel('Standardised Price')

plt.show()

# %% [markdown]
# This time both training loss and test loss share a stronger resemblance, as expected. Moreover, predictions track actuals much more accurately during the COVID-19 period.

# %% [markdown]
# ## Experimentation
# Now we consider a number of experiments. Before doing so, we first wrap some of the above code into functions.

# %%
def train_model(train_dataloader, test_dataloader, 
                  network, optimizer, criterion, n_epochs, 
                  experiment_name, window_length=25):
    
    train_losses = []
    test_losses = []

    for e in range(n_epochs):

        network.train()
        for ii, (inputs, responses) in enumerate(train_dataloader):
            optimizer.zero_grad() 

            output = network(inputs)
            loss = criterion(output, responses)

            loss.backward()
            optimizer.step()

            train_losses.append(loss.item() / inputs.shape[0])


        test_loss = 0

        network.eval()
        for ii, (inputs, responses) in enumerate(test_dataloader):
            with torch.no_grad():
                output = network(inputs)
                loss = criterion(output, responses)

                test_loss += loss.item() / inputs.shape[0]

        test_losses.append(test_loss)
        
    train_losses_averaged = np.convolve(np.array(train_losses), 
                                        np.ones((window_length,)) / window_length, 
                                        mode='valid')
    
    network.eval()
    with torch.no_grad():
        predictions = network(torch.from_numpy(X).type(torch.float)).numpy()
    
    predictions_1step = pd.Series(predictions[:,0], index=series_standardised.index[5:-5])
    predictions_5step = pd.Series(predictions[:,0], index=series_standardised.index[5:-5])
    
    results = {'train_losses': train_losses,
               'train_losses_averaged': train_losses_averaged,
               'test_losses': test_losses, 
               'predictions_1step': predictions_1step,
               'predictions_5step': predictions_5step,
               'experiment_name': experiment_name}
    return results

def plot_results(experiment_results, window_length=25):
    
    fig = plt.figure(figsize=(20,12))
    gs = GridSpec(2, 2, figure=fig)
    ax1 = plt.subplot(gs[0, :])
    ax2 = plt.subplot(gs[1, :])
    
    for experiment in experiment_results:
        ax1.plot(experiment['train_losses_averaged'],
                 label=experiment['experiment_name'])
        ax2.plot(experiment['test_losses'], alpha=0.8)

    ax1.set_title('Training loss (mean per {} batches)'.format(str(window_length)))
    ax1.set_xlabel('Batch')
    ax1.set_ylabel('Loss')
    ax1.legend(loc='upper right')

    ax2.set_title('Test loss (per epoch)')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')

# %%
train_dataset_1 = TensorDataset(
    torch.from_numpy(X_train_1).type(torch.float),
    torch.from_numpy(y_train_1).type(torch.float),
)

train_dataloader_1 = DataLoader(train_dataset_1, batch_size=32, shuffle=True)

test_dataset_1 = TensorDataset(
    torch.from_numpy(X_test_1).type(torch.float),
    torch.from_numpy(y_test_1).type(torch.float),
)

test_dataloader_1 = DataLoader(test_dataset_1, batch_size=32, shuffle=True)


train_dataset_2 = TensorDataset(
    torch.from_numpy(X_train_2).type(torch.float),
    torch.from_numpy(y_train_2).type(torch.float),
)

train_dataloader_2 = DataLoader(train_dataset_2, batch_size=32, shuffle=True)

test_dataset_2 = TensorDataset(
    torch.from_numpy(X_test_2).type(torch.float),
    torch.from_numpy(y_test_2).type(torch.float),
)

test_dataloader_2 = DataLoader(test_dataset_2, batch_size=32, shuffle=True)

# %% [markdown]
# ### 1. Optimisers
# Let us first consider the effects of two different optimisers: Adam and SGD. To make the latter more interesting, we add some momentum.

# %%
model_adam = Net()
optimiser_adam = optim.AdamW(model_adam.parameters(), lr=0.0005)

model_SGD = Net()
optimiser_SGD = optim.SGD(model_SGD.parameters(), lr=0.0005)

results_adam = train_model(train_dataloader_2, test_dataloader_2, 
                             model_adam, optimiser_adam,
                             nn.MSELoss(), 250, 
                             'AdamW')
results_SGD = train_model(train_dataloader_2, test_dataloader_2,
                            model_SGD, optimiser_SGD,
                            nn.MSELoss(), 250, 
                            'SGD')

experiment_results = [results_adam, results_SGD]

# %%
plot_results(experiment_results)

# %% [markdown]
# ### 2. Learning Rate and Momentum
# Since SGD has had more consistent success, we experiment with the learning rate and momentum applied to it.

# %%
plot_results(experiment_results)

# %% [markdown]
# ### 3. Network Depth
# Next we experiment with the actual structure of the network which is being trained. In particular, we will try adding layers to the network. To this end, I first define a simple ```QuickNet``` class which takes as initialisation arguments a list of layer sizes.

# %%
class QuickNet(nn.Module):
    def __init__(self, layer_sizes):
        super().__init__()

        self.layer_sizes = layer_sizes

        structure = []
        for i in range(len(layer_sizes)):
            if i == len(layer_sizes) - 2:
                structure.append(nn.Linear(layer_sizes[i], layer_sizes[i+1]))
                break
            else:
                structure.append(nn.Linear(layer_sizes[i], layer_sizes[i+1]))
                structure.append(nn.ReLU())

        self.layers = nn.ModuleList(structure)

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
plot_results(experiment_results)

# %% [markdown]
# ### 4. Network Width
# Last we experiment with the width of the network. This is again done using the ```QuickNet``` class.

# %%
plot_results(experiment_results)

# %% [markdown]
# ## Evaluation
# Across the above, we have explored the performance of various network configurations. Now we pick the best.
